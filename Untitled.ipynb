# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv("cleaned_data.csv")
df.head(25)
# Out:
#                ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  \
# 0   798fc410-45c1      20000    2          2         1   24      2      2
# 1   8a8c8f3b-8eb4     120000    2          2         2   26     -1      2
# 2   85698822-43f5      90000    2          2         2   34      0      0
# 3   0737c11b-be42      50000    2          2         1   37      0      0
# 4   3b7f77cc-dbc0      50000    1          2         1   57     -1      0
# 5   ceae2946-47e4      50000    1          1         2   37      0      0
# 6   d3b8ce26-9c89     500000    1          1         2   29      0      0
# 7   d6e1911b-54d0     100000    2          2         2   23      0     -1
# 8   8421d3b3-2b54     140000    2          3         1   28      0      0
# 9   62a2fd79-cd90      20000    1          3         2   35     -2     -2
# 10  b73c34fc-91cf     200000    2          3         2   34      0      0
# 11  4777689a-5131     260000    2          1         2   51     -1     -1
# ...

# %%
df.drop("ID",axis = 1, inplace = True)

# %%
d1 = {"high school":1, 
     "university":2,}
df['EDUCATION_CAT'] = df.EDUCATION_CAT.map(d1)
df["EDUCATION_CAT"] = df["EDUCATION_CAT"].fillna(0)

# %%
df['EDUCATION_CAT'].value_counts(dropna = False)
# Out:
# 2.0    12458
# 0.0     9826
# 1.0     4380
# Name: EDUCATION_CAT, dtype: int64

# %%
df.isna().sum()
# Out:
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_1                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# EDUCATION_CAT                 0
# graduate school               0
# high school                   0
# others                        0
# university                    0
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
oneHot = OneHotEncoder(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1', 'PAY_2',
       'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
       'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
       'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
       'EDUCATION_CAT', 'graduate school',
       'high school', 'others', 'university'])
column_features = []
transformer = ColumnTransformer([("onehot", oneHot, column_features)], remainder = "passthrough")
transformed_x = transformer.fit_transform(x)
transformed_x
x = pd.DataFrame(transformed_x)

# %%
y = df["default payment next month"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y , test_size = 0.2)

# %%
clf = LogisticRegression();
clf.fit(x_train,y_train)
# Out:
# C:\Users\jz\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
clf.score(x_test,y_test)
# Out:
# 0.7916744796549784

# %%
y_preds = clf.predict_proba(x_test)
y_preds
# Out:
# array([[0.76155516, 0.23844484],
#        [0.52682617, 0.47317383],
#        [0.86364757, 0.13635243],
#        ...,
#        [0.92375239, 0.07624761],
#        [0.71510479, 0.28489521],
#        [0.78820729, 0.21179271]])

# %%
from sklearn.metrics import roc_curve,plot_roc_curve, confusion_matrix, classification_report

# %%
plot_roc_curve(clf, x_test, y_test)

# %%
y_preds_positive = y_preds[:,1]

# %%
fpr, tpr , thresholds = roc_curve(y_test, y_preds_positive)

# %%
import matplotlib.pyplot as plt
def plot_roc_curve(fpr, tpr):
    plt.plot(fpr, tpr, color = "orange", Label = "ROC")
    plt.plot([0,1],[0,1], color = "blue", linestyle = "--", label = "Guessing" )
    plt.title("roc_curve")
    plt.xlabel("fbr")
    plt.ylabel("tpr")
    plt.legend()
    plt.show()

# %%
plot_roc_curve(fpr, tpr)
